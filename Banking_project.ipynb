# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Admin\OneDrive\Documents\Data_science\Machine_Learning Notes and projects\ml_project_on(bank_and_telecomunication)\credit_risk_dataset.csv")

# %%
df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
duplicate=df.duplicated()

# %%
df[duplicate]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 15975          23          42000                  RENT                5.0
# 15989          23          90000              MORTGAGE                7.0
# 15995          24          48000              MORTGAGE                4.0
# 16025          24          10000                  RENT                8.0
# 16028          23         100000              MORTGAGE                7.0
# ...           ...            ...                   ...                ...
# 32010          42          39996              MORTGAGE                2.0
# 32047          36         250000                  RENT                2.0
# 32172          49         120000              MORTGAGE               12.0
# 32259          39          40000                   OWN                4.0
# 32279          43          11340                  RENT                4.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
df.shape
# Out:
# (32581, 12)

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## After droping all duplicate rows in dataframe

# %%
df.shape
# Out:
# (32416, 12)

# %%
df.isnull().sum()
# Out:
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length              887
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3095
# loan_status                      0
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %%
df.isnull().sum()*100/len(df)
# Out:
# person_age                    0.000000
# person_income                 0.000000
# person_home_ownership         0.000000
# person_emp_length             2.736303
# loan_intent                   0.000000
# loan_grade                    0.000000
# loan_amnt                     0.000000
# loan_int_rate                 9.547754
# loan_status                   0.000000
# loan_percent_income           0.000000
# cb_person_default_on_file     0.000000
# cb_person_cred_hist_length    0.000000
# dtype: float64

# %%
df.describe()
# Out:
#          person_age  person_income  person_emp_length     loan_amnt  \
# count  32416.000000   3.241600e+04        31529.00000  32416.000000
# mean      27.747008   6.609164e+04            4.79051   9593.845632
# std        6.354100   6.201558e+04            4.14549   6322.730241
# min       20.000000   4.000000e+03            0.00000    500.000000
# 25%       23.000000   3.854200e+04            2.00000   5000.000000
# 50%       26.000000   5.500000e+04            4.00000   8000.000000
# 75%       30.000000   7.921800e+04            7.00000  12250.000000
# max      144.000000   6.000000e+06          123.00000  35000.000000
#
#        loan_int_rate   loan_status  loan_percent_income  \
# count   29321.000000  32416.000000         32416.000000
# mean       11.017265      0.218688             0.170250
# std         3.241680      0.413363             0.106812
# min         5.420000      0.000000             0.000000
# 25%         7.900000      0.000000             0.090000
# ...

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=df,x="person_age");

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=df,x="person_emp_length");

# %%
df[df.person_emp_length>18]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 0              22          59000                  RENT              123.0
# 210            21         192000              MORTGAGE              123.0
# 17905          35         280000              MORTGAGE               19.0
# 17997          35         200004              MORTGAGE               19.0
# 18077          35          80000                  RENT               19.0
# ...           ...            ...                   ...                ...
# 32515          53         106000              MORTGAGE               38.0
# 32516          52          29000                   OWN               23.0
# 32534          76          75000                  RENT               23.0
# 32539          61         148000              MORTGAGE               30.0
# 32562          61         160000              MORTGAGE               30.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
df = df[~(df['person_emp_length'] >=18)]

# %%
df[df['person_emp_length']==19]
# Out:
# Empty DataFrame
# Columns: [person_age, person_income, person_home_ownership, person_emp_length, loan_intent, loan_grade, loan_amnt, loan_int_rate, loan_status, loan_percent_income, cb_person_default_on_file, cb_person_cred_hist_length]
# Index: []

# %%
df[df.person_age>50]
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 81            144         250000                  RENT                4.0
# 183           144         200000              MORTGAGE                4.0
# 575           123          80004                  RENT                2.0
# 747           123          78000                  RENT                7.0
# 32297         144        6000000              MORTGAGE               12.0
# ...           ...            ...                   ...                ...
# 32576          57          53000              MORTGAGE                1.0
# 32577          54         120000              MORTGAGE                4.0
# 32578          65          76000                  RENT                3.0
# 32579          56         150000              MORTGAGE                5.0
# 32580          66          42000                  RENT                2.0
#
#            loan_intent loan_grade  loan_amnt  loan_int_rate  loan_status  \
# ...

# %%
df = df[~(df['person_age'] >=50)]

# %%
df.shape
# Out:
# (31780, 12)

# %%
df.isnull().sum()
# Out:
# person_age                       0
# person_income                    0
# person_home_ownership            0
# person_emp_length              882
# loan_intent                      0
# loan_grade                       0
# loan_amnt                        0
# loan_int_rate                 3030
# loan_status                      0
# loan_percent_income              0
# cb_person_default_on_file        0
# cb_person_cred_hist_length       0
# dtype: int64

# %%
np.round(df.person_emp_length.mean(),2)

np.round(df.person_emp_length.median(),2)
# Out:
# 4.63
# 4.0

# %%
df.loan_int_rate.mean()

df.loan_int_rate.median()
# Out:
# 11.014040347825462
# 10.99

# %%
df.loan_percent_income.tail()
# Out:
# 32291    0.04
# 32292    0.01
# 32293    0.15
# 32295    0.25
# 32296    0.29
# Name: loan_percent_income, dtype: float64

# %%
df.person_emp_length=df.person_emp_length.fillna(np.round(df.person_emp_length.median(),2))

# %%
df.loan_int_rate=df.loan_int_rate.fillna(df.loan_int_rate.median())

# %%
df.isnull().sum()
# Out:
# person_age                    0
# person_income                 0
# person_home_ownership         0
# person_emp_length             0
# loan_intent                   0
# loan_grade                    0
# loan_amnt                     0
# loan_int_rate                 0
# loan_status                   0
# loan_percent_income           0
# cb_person_default_on_file     0
# cb_person_cred_hist_length    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31780 entries, 1 to 32296
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  31780 non-null  int64
#  1   person_income               31780 non-null  int64
#  2   person_home_ownership       31780 non-null  object
#  3   person_emp_length           31780 non-null  float64
#  4   loan_intent                 31780 non-null  object
#  5   loan_grade                  31780 non-null  object
#  6   loan_amnt                   31780 non-null  int64
#  7   loan_int_rate               31780 non-null  float64
#  8   loan_status                 31780 non-null  int64
#  9   loan_percent_income         31780 non-null  float64
#  10  cb_person_default_on_file   31780 non-null  object
#  11  cb_person_cred_hist_length  31780 non-null  int64
# dtypes: float64(3), int64(5), object(4)
# memory usage: 3.2+ MB

# %% [markdown]
# Here in dataset  target variable is loan_status so i have passed all variables using a list to consider target varibale as (y) and remaining all variable as (X)

# %%
df=df[["person_age","person_income",'person_home_ownership','person_emp_length', 'loan_intent','loan_grade','loan_amnt', 'loan_int_rate','loan_percent_income','cb_person_default_on_file', 'cb_person_cred_hist_length','loan_status']]

# %%
df
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 1              21           9600                   OWN                5.0
# 2              25           9600              MORTGAGE                1.0
# 3              23          65500                  RENT                4.0
# 4              24          54400                  RENT                8.0
# 5              21           9900                   OWN                2.0
# ...           ...            ...                   ...                ...
# 32291          42         600000                 OTHER                2.0
# 32292          38         200000              MORTGAGE                0.0
# 32293          38         110000              MORTGAGE                5.0
# 32295          42         101000              MORTGAGE                6.0
# 32296          40          52000                  RENT                2.0
#
#              loan_intent loan_grade  loan_amnt  loan_int_rate  \
# ...

# %% [markdown]
# here we asssume targed value as y and remaining columns as X

# %%
y=df["loan_status"]

X=df[["person_age","person_income",'person_home_ownership','person_emp_length', 'loan_intent','loan_grade','loan_amnt', 'loan_int_rate','loan_percent_income','cb_person_default_on_file', 'cb_person_cred_hist_length']]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train,y_test = train_test_split(X,y,train_size=0.75,random_state=100)

# %%
X_train.shape
# Out:
# (23835, 11)

# %%
X_test.shape
# Out:
# (7945, 11)

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23835 entries, 28102 to 5646
# Data columns (total 11 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   person_age                  23835 non-null  int64
#  1   person_income               23835 non-null  int64
#  2   person_home_ownership       23835 non-null  object
#  3   person_emp_length           23835 non-null  float64
#  4   loan_intent                 23835 non-null  object
#  5   loan_grade                  23835 non-null  object
#  6   loan_amnt                   23835 non-null  int64
#  7   loan_int_rate               23835 non-null  float64
#  8   loan_percent_income         23835 non-null  float64
#  9   cb_person_default_on_file   23835 non-null  object
#  10  cb_person_cred_hist_length  23835 non-null  int64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 2.2+ MB

# %% [markdown]
# Here i splitted X_train dataset into X_train_num (numerical)  and  X_train_cat (categorical)

# %%
X_train_num= X_train.select_dtypes(include=["int64","float64"])

X_train_num
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 28102          28          71400                5.0       5000          11.12
# 2669           26          44000                0.0       3000           7.49
# 26091          30          80000                5.0      13600          12.42
# 2445           22          32000                1.0       1200           9.96
# 15371          25         131000                1.0       7500          12.29
# ...           ...            ...                ...        ...            ...
# 12125          24          74000                3.0      11500          10.74
# 24590          35          75000                5.0       4000          14.27
# 14153          23         100000                4.0      10000          12.87
# 23477          28          63000                3.0      13500          13.23
# 5646           23          45600                7.0       1000           9.62
#
# ...

# %%
X_train_cat=X_train.select_dtypes(include=["object"])

X_train_cat
# Out:
#       person_home_ownership        loan_intent loan_grade  \
# 28102                  RENT            MEDICAL          B
# 2669                   RENT    HOMEIMPROVEMENT          A
# 26091                  RENT           PERSONAL          B
# 2445                    OWN            MEDICAL          B
# 15371              MORTGAGE           PERSONAL          C
# ...                     ...                ...        ...
# 12125                  RENT          EDUCATION          B
# 24590              MORTGAGE  DEBTCONSOLIDATION          C
# 14153              MORTGAGE          EDUCATION          C
# 23477              MORTGAGE            VENTURE          C
# 5646                    OWN            MEDICAL          B
#
#       cb_person_default_on_file
# 28102                         N
# 2669                          N
# 26091                         N
# 2445                          N
# 15371                         N
# ...                         ...
# 12125                         N
# ...

# %% [markdown]
# Smillarly i splitted X_test dataset into X_test_num (numerical) and X_test_cat (categorical)

# %%
X_test_num= X_test.select_dtypes(include=["int64","float64"])

X_test_num
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 83             26         110000               10.0      28000           8.90
# 19981          28          65000                9.0      10400           5.42
# 17895          32         288000                8.0      25000          14.83
# 13601          23          94800                7.0       6000          14.27
# 4620           22          42000                1.0      10500          14.65
# ...           ...            ...                ...        ...            ...
# 15695          24          48000                4.0      15200          11.48
# 16125          23          75000                5.0       5000          11.12
# 29757          43          90000                5.0      10400          11.49
# 31547          39          96500                4.0      14400          15.20
# 25074          30          80000                2.0       6000          14.17
#
# ...

# %%
X_test_cat=X_test.select_dtypes(include=["object"])

X_test_cat
# Out:
#       person_home_ownership        loan_intent loan_grade  \
# 83                     RENT          EDUCATION          A
# 19981                  RENT           PERSONAL          A
# 17895              MORTGAGE  DEBTCONSOLIDATION          D
# 13601              MORTGAGE  DEBTCONSOLIDATION          C
# 4620               MORTGAGE           PERSONAL          C
# ...                     ...                ...        ...
# 15695                  RENT  DEBTCONSOLIDATION          B
# 16125              MORTGAGE           PERSONAL          B
# 29757                  RENT  DEBTCONSOLIDATION          B
# 31547                  RENT  DEBTCONSOLIDATION          D
# 25074              MORTGAGE            VENTURE          C
#
#       cb_person_default_on_file
# 83                            N
# 19981                         N
# 17895                         Y
# 13601                         Y
# 4620                          N
# ...                         ...
# 15695                         N
# ...

# %% [markdown]
# # datapreprocessing steps from here

# %% [markdown]
# Scaling a scaler difference

# %%
from sklearn.preprocessing import StandardScaler

num_encode=StandardScaler()

X_train_num_rescaled = pd.DataFrame(num_encode.fit_transform(X_train_num), 
                                    columns = X_train_num.columns, 
                                    index = X_train_num.index)

# %%
X_train_num_rescaled
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 28102    0.119250       0.119989           0.109111  -0.726829       0.038392
# 2669    -0.251400      -0.429925          -1.255781  -1.044531      -1.141343
# 26091    0.489901       0.292590           0.109111   0.639291       0.460887
# 2445    -0.992701      -0.670764          -0.982802  -1.330463      -0.338603
# 15371   -0.436725       1.316154          -0.982802  -0.329701       0.418637
# ...           ...            ...                ...        ...            ...
# 12125   -0.622051       0.172171          -0.436846   0.305704      -0.085106
# 24590    1.416527       0.192241           0.109111  -0.885680       1.062129
# 14153   -0.807376       0.693988          -0.163867   0.067427       0.607135
# 23477    0.119250      -0.048598          -0.436846   0.623406       0.724133
# 5646    -0.807376      -0.397813           0.655068  -1.362234      -0.449102
#
# ...

# %%
X_train_cat
# Out:
#       person_home_ownership        loan_intent loan_grade  \
# 28102                  RENT            MEDICAL          B
# 2669                   RENT    HOMEIMPROVEMENT          A
# 26091                  RENT           PERSONAL          B
# 2445                    OWN            MEDICAL          B
# 15371              MORTGAGE           PERSONAL          C
# ...                     ...                ...        ...
# 12125                  RENT          EDUCATION          B
# 24590              MORTGAGE  DEBTCONSOLIDATION          C
# 14153              MORTGAGE          EDUCATION          C
# 23477              MORTGAGE            VENTURE          C
# 5646                    OWN            MEDICAL          B
#
#       cb_person_default_on_file
# 28102                         N
# 2669                          N
# 26091                         N
# 2445                          N
# 15371                         N
# ...                         ...
# 12125                         N
# ...

# %%
X_train_cat.person_home_ownership.unique()

X_train_cat.loan_intent.unique()

X_train_cat.loan_grade.unique()
# Out:
# array(['RENT', 'OWN', 'MORTGAGE', 'OTHER'], dtype=object)
# array(['MEDICAL', 'HOMEIMPROVEMENT', 'PERSONAL', 'DEBTCONSOLIDATION',
#        'EDUCATION', 'VENTURE'], dtype=object)
# array(['B', 'A', 'C', 'D', 'E', 'F', 'G'], dtype=object)

# %%
X_train_cat_le = pd.DataFrame(index=X_train_cat.index)

X_train_cat_le.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [28102, 2669, 26091, 2445, 15371]

# %%
loan_grade_encoder = {'A' : 1, 'B' : 2, 'C' : 3, 'D' : 4, 'E' : 5,"F":6,"G":7}

X_train_cat_le['loan_grade'] = X_train_cat['loan_grade'].apply(lambda x :loan_grade_encoder[x])

X_train_cat_le.head()
# Out:
#        loan_grade
# 28102           2
# 2669            1
# 26091           2
# 2445            2
# 15371           3

# %%
X_train_cat=X_train_cat[["person_home_ownership","loan_intent","cb_person_default_on_file"]]

# %%
X_train_cat
# Out:
#       person_home_ownership        loan_intent cb_person_default_on_file
# 28102                  RENT            MEDICAL                         N
# 2669                   RENT    HOMEIMPROVEMENT                         N
# 26091                  RENT           PERSONAL                         N
# 2445                    OWN            MEDICAL                         N
# 15371              MORTGAGE           PERSONAL                         N
# ...                     ...                ...                       ...
# 12125                  RENT          EDUCATION                         N
# 24590              MORTGAGE  DEBTCONSOLIDATION                         Y
# 14153              MORTGAGE          EDUCATION                         Y
# 23477              MORTGAGE            VENTURE                         N
# 5646                    OWN            MEDICAL                         N
#
# [23835 rows x 3 columns]

# %% [markdown]
# OneHotEncoding the categorical features

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first', sparse=False)

X_train_cat_ohe = pd.DataFrame(encoder.fit_transform(X_train_cat), 
                               columns=encoder.get_feature_names(X_train_cat.columns), 
                               index = X_train_cat.index)


X_train_cat_ohe
# Out:
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 28102                          0.0                        0.0
# 2669                           0.0                        0.0
# 26091                          0.0                        0.0
# 2445                           0.0                        1.0
# 15371                          0.0                        0.0
# ...                            ...                        ...
# 12125                          0.0                        0.0
# 24590                          0.0                        0.0
# 14153                          0.0                        0.0
# 23477                          0.0                        0.0
# 5646                           0.0                        1.0
#
#        person_home_ownership_RENT  loan_intent_EDUCATION  \
# 28102                         1.0                    0.0
# 2669                          1.0                    0.0
# ...

# %% [markdown]
# Applying label encoding

# %%
X_train_categorical=pd.concat([X_train_cat_ohe,X_train_cat_le],axis=1)

X_train_categorical.head()
# Out:
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 28102                          0.0                        0.0
# 2669                           0.0                        0.0
# 26091                          0.0                        0.0
# 2445                           0.0                        1.0
# 15371                          0.0                        0.0
#
#        person_home_ownership_RENT  loan_intent_EDUCATION  \
# 28102                         1.0                    0.0
# 2669                          1.0                    0.0
# 26091                         1.0                    0.0
# 2445                          0.0                    0.0
# 15371                         0.0                    0.0
#
#        loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 28102                          0.0                  1.0                   0.0
# 2669                           1.0                  0.0                   0.0
# ...

# %%
X_train_transformed = pd.concat([X_train_num_rescaled, X_train_categorical], axis=1)

X_train_transformed.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 28102    0.119250       0.119989           0.109111  -0.726829       0.038392
# 2669    -0.251400      -0.429925          -1.255781  -1.044531      -1.141343
# 26091    0.489901       0.292590           0.109111   0.639291       0.460887
# 2445    -0.992701      -0.670764          -0.982802  -1.330463      -0.338603
# 15371   -0.436725       1.316154          -0.982802  -0.329701       0.418637
#
#        loan_percent_income  cb_person_cred_hist_length  \
# 28102            -1.035239                    0.663182
# 2669             -0.941668                   -0.437235
# 26091            -0.005959                    0.938286
# 2445             -1.222381                   -0.987444
# 15371            -1.035239                   -0.712340
#
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 28102                          0.0                        0.0
# ...

# %%
X_train_transformed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23835 entries, 28102 to 5646
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   person_age                   23835 non-null  float64
#  1   person_income                23835 non-null  float64
#  2   person_emp_length            23835 non-null  float64
#  3   loan_amnt                    23835 non-null  float64
#  4   loan_int_rate                23835 non-null  float64
#  5   loan_percent_income          23835 non-null  float64
#  6   cb_person_cred_hist_length   23835 non-null  float64
#  7   person_home_ownership_OTHER  23835 non-null  float64
#  8   person_home_ownership_OWN    23835 non-null  float64
#  9   person_home_ownership_RENT   23835 non-null  float64
#  10  loan_intent_EDUCATION        23835 non-null  float64
#  11  loan_intent_HOMEIMPROVEMENT  23835 non-null  float64
# ...

# %% [markdown]
# # preparing test data set

# %%
X_test.head(20)
# Out:
#        person_age  person_income person_home_ownership  person_emp_length  \
# 83             26         110000                  RENT               10.0
# 19981          28          65000                  RENT                9.0
# 17895          32         288000              MORTGAGE                8.0
# 13601          23          94800              MORTGAGE                7.0
# 4620           22          42000              MORTGAGE                1.0
# 31960          37          74568                  RENT                0.0
# 24668          34          69204                  RENT                4.0
# 28705          28          30000                  RENT                2.0
# 1231           21          41900                  RENT                2.0
# 2690           22          48609                  RENT                6.0
# 12008          25          68000                  RENT                4.0
# 14190          22          30000                   OWN                3.0
# ...

# %%
X_test_cat
# Out:
#       person_home_ownership        loan_intent loan_grade  \
# 83                     RENT          EDUCATION          A
# 19981                  RENT           PERSONAL          A
# 17895              MORTGAGE  DEBTCONSOLIDATION          D
# 13601              MORTGAGE  DEBTCONSOLIDATION          C
# 4620               MORTGAGE           PERSONAL          C
# ...                     ...                ...        ...
# 15695                  RENT  DEBTCONSOLIDATION          B
# 16125              MORTGAGE           PERSONAL          B
# 29757                  RENT  DEBTCONSOLIDATION          B
# 31547                  RENT  DEBTCONSOLIDATION          D
# 25074              MORTGAGE            VENTURE          C
#
#       cb_person_default_on_file
# 83                            N
# 19981                         N
# 17895                         Y
# 13601                         Y
# 4620                          N
# ...                         ...
# 15695                         N
# ...

# %%
X_test_num
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 83             26         110000               10.0      28000           8.90
# 19981          28          65000                9.0      10400           5.42
# 17895          32         288000                8.0      25000          14.83
# 13601          23          94800                7.0       6000          14.27
# 4620           22          42000                1.0      10500          14.65
# ...           ...            ...                ...        ...            ...
# 15695          24          48000                4.0      15200          11.48
# 16125          23          75000                5.0       5000          11.12
# 29757          43          90000                5.0      10400          11.49
# 31547          39          96500                4.0      14400          15.20
# 25074          30          80000                2.0       6000          14.17
#
# ...

# %%
X_test_num_rescaled = pd.DataFrame(num_encode.transform(X_test_num), 
                                   columns = X_test_num.columns, 
                                   index = X_test_num.index)

X_test_num_rescaled.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 83      -0.251400       0.894687           1.474003   2.926748      -0.683099
# 19981    0.119250      -0.008458           1.201025   0.130967      -1.814084
# 17895    0.860552       4.467125           0.928046   2.450194       1.244127
# 13601   -0.807376       0.589625           0.655068  -0.567978       1.062129
# 4620    -0.992701      -0.470065          -0.982802   0.146852       1.185627
#
#        loan_percent_income  cb_person_cred_hist_length
# 83                0.742608                   -0.987444
# 19981            -0.099530                    0.663182
# 17895            -0.754526                    1.213391
# 13601            -1.035239                   -0.712340
# 4620              0.742608                   -0.987444

# %%
X_test_cat_le = pd.DataFrame(index = X_test_cat.index)

X_test_cat_le.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [83, 19981, 17895, 13601, 4620]

# %%
loan_grade_encoder = {'A' : 1, 'B' : 2, 'C' : 3, 'D' : 4, 'E' : 5,"F":6,"G":7}

X_test_cat_le['loan_grade'] = X_test_cat['loan_grade'].apply(lambda x :loan_grade_encoder[x])

X_test_cat_le.head()
# Out:
#        loan_grade
# 83              1
# 19981           1
# 17895           4
# 13601           3
# 4620            3

# %%
X_test_categorical=X_test_cat[["person_home_ownership","loan_intent","cb_person_default_on_file"]]

# %%
X_test_categorical
# Out:
#       person_home_ownership        loan_intent cb_person_default_on_file
# 83                     RENT          EDUCATION                         N
# 19981                  RENT           PERSONAL                         N
# 17895              MORTGAGE  DEBTCONSOLIDATION                         Y
# 13601              MORTGAGE  DEBTCONSOLIDATION                         Y
# 4620               MORTGAGE           PERSONAL                         N
# ...                     ...                ...                       ...
# 15695                  RENT  DEBTCONSOLIDATION                         N
# 16125              MORTGAGE           PERSONAL                         N
# 29757                  RENT  DEBTCONSOLIDATION                         N
# 31547                  RENT  DEBTCONSOLIDATION                         N
# 25074              MORTGAGE            VENTURE                         Y
#
# [7945 rows x 3 columns]

# %%
from sklearn.preprocessing import OneHotEncoder

encoder = OneHotEncoder(drop='first', sparse=False)

X_test_cat_ohe = pd.DataFrame(encoder.fit_transform(X_test_categorical), 
                               columns=encoder.get_feature_names(X_test_categorical.columns), 
                               index = X_test_categorical.index)


X_test_cat_ohe
# Out:
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 83                             0.0                        0.0
# 19981                          0.0                        0.0
# 17895                          0.0                        0.0
# 13601                          0.0                        0.0
# 4620                           0.0                        0.0
# ...                            ...                        ...
# 15695                          0.0                        0.0
# 16125                          0.0                        0.0
# 29757                          0.0                        0.0
# 31547                          0.0                        0.0
# 25074                          0.0                        0.0
#
#        person_home_ownership_RENT  loan_intent_EDUCATION  \
# 83                            1.0                    1.0
# 19981                         1.0                    0.0
# ...

# %%
X_test_categorical2=pd.concat([X_test_cat_ohe,X_test_cat_le],axis=1)

X_test_categorical2.head()
# Out:
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 83                             0.0                        0.0
# 19981                          0.0                        0.0
# 17895                          0.0                        0.0
# 13601                          0.0                        0.0
# 4620                           0.0                        0.0
#
#        person_home_ownership_RENT  loan_intent_EDUCATION  \
# 83                            1.0                    1.0
# 19981                         1.0                    0.0
# 17895                         0.0                    0.0
# 13601                         0.0                    0.0
# 4620                          0.0                    0.0
#
#        loan_intent_HOMEIMPROVEMENT  loan_intent_MEDICAL  loan_intent_PERSONAL  \
# 83                             0.0                  0.0                   0.0
# 19981                          0.0                  0.0                   1.0
# ...

# %%
X_test_transformed = pd.concat([X_test_num_rescaled, X_test_categorical2], axis=1)

X_test_transformed.head()
# Out:
#        person_age  person_income  person_emp_length  loan_amnt  loan_int_rate  \
# 83      -0.251400       0.894687           1.474003   2.926748      -0.683099
# 19981    0.119250      -0.008458           1.201025   0.130967      -1.814084
# 17895    0.860552       4.467125           0.928046   2.450194       1.244127
# 13601   -0.807376       0.589625           0.655068  -0.567978       1.062129
# 4620    -0.992701      -0.470065          -0.982802   0.146852       1.185627
#
#        loan_percent_income  cb_person_cred_hist_length  \
# 83                0.742608                   -0.987444
# 19981            -0.099530                    0.663182
# 17895            -0.754526                    1.213391
# 13601            -1.035239                   -0.712340
# 4620              0.742608                   -0.987444
#
#        person_home_ownership_OTHER  person_home_ownership_OWN  \
# 83                             0.0                        0.0
# ...

# %% [markdown]
# #  Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
regressor = LogisticRegression()
regressor.fit(X_train_transformed, y_train)
# Out:
# LogisticRegression()

# %%
y_test_pred = regressor.predict(X_test_transformed)

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})

temp_df.head()
# Out:
#        Actual  Predicted
# 83          0          0
# 19981       0          0
# 17895       1          0
# 13601       0          0
# 4620        0          0

# %%
 from sklearn.metrics import accuracy_score
L=('Acurracy Absolute Error: ',accuracy_score(y_test, y_test_pred))
L
# Out:
# ('Acurracy Absolute Error: ', 0.8555066079295154)

# %% [markdown]
# # KNN classification

# %%
from sklearn.neighbors import KNeighborsClassifier

classifier=KNeighborsClassifier()
classifier.fit(X_train_transformed, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_test_pred = classifier.predict(X_test_transformed)

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})

temp_df.head()
# Out:
#        Actual  Predicted
# 83          0          0
# 19981       0          0
# 17895       1          0
# 13601       0          0
# 4620        0          0

# %%
 from sklearn.metrics import accuracy_score

k=('Acurracy Absolute Error: ',accuracy_score(y_test, y_test_pred))
k
# Out:
# ('Acurracy Absolute Error: ', 0.8872246696035242)

# %% [markdown]
# # svm

# %%
from sklearn import svm
clf = svm.SVC()
clf.fit(X_train_transformed, y_train)
# Out:
# SVC()

# %%
y_test_pred = clf.predict(X_test_transformed)

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})

temp_df.head()
# Out:
#        Actual  Predicted
# 83          0          0
# 19981       0          0
# 17895       1          0
# 13601       0          0
# 4620        0          0

# %%
from sklearn.metrics import accuracy_score

s=('Acurracy Absolute Error: ',accuracy_score(y_test, y_test_pred))
s
# Out:
# ('Acurracy Absolute Error: ', 0.908747640025173)

# %% [markdown]
# # Decision tree

# %%
from sklearn import tree
clfs = tree.DecisionTreeClassifier()
clfs.fit(X_train_transformed, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_test_pred = clfs.predict(X_test_transformed)

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})

temp_df.head()
# Out:
#        Actual  Predicted
# 83          0          0
# 19981       0          0
# 17895       1          1
# 13601       0          0
# 4620        0          0

# %%
from sklearn.metrics import accuracy_score

d=('Acurracy Absolute Error: ',accuracy_score(y_test, y_test_pred))
d
# Out:
# ('Acurracy Absolute Error: ', 0.890119572057898)

# %% [markdown]
# # Random forest classifier

# %%
from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier()
RF.fit(X_train_transformed, y_train)
# Out:
# RandomForestClassifier()

# %%
y_test_pred = RF.predict(X_test_transformed)

# %%
temp_df = pd.DataFrame({'Actual': y_test, 'Predicted': y_test_pred})

temp_df.head()
# Out:
#        Actual  Predicted
# 83          0          0
# 19981       0          0
# 17895       1          1
# 13601       0          0
# 4620        0          0

# %%
from sklearn.metrics import accuracy_score

f=('Acurracy Absolute Error: ',accuracy_score(y_test, y_test_pred))
f
# Out:
# ('Acurracy Absolute Error: ', 0.9368156073001888)

# %%
dict1 = {"Algorithm": ["logistic_Regression", "KNN", "SVM", "Decission_tree", "RandomForest_classifier"],
           "Evaluate_score": [0.8555066079295154, 0.8872246696035242, 0.908747640025173, 0.890119572057898, 0.9368156073001888]}

# %%
score=pd.DataFrame(dict1)

# %%
score
# Out:
#                  Algorithm  Evaluate_score
# 0      logistic_Regression        0.855507
# 1                      KNN        0.887225
# 2                      SVM        0.908748
# 3           Decission_tree        0.890120
# 4  RandomForest_classifier        0.936816

# %%
plt.figure(figsize=(15,5))
sns.lineplot(data=score,x="Algorithm",y="Evaluate_score",marker=".",color = '#464196',markersize = '30');

# %% [markdown]
# # conclusion
#
# IN these data frame Target varibale was Loan_status , as problem statment was to predict of loan defaulters, so that bank can reduce non-performing assets , so based on the given statemment and target variable,selected supervised method and task taken classifer task, so i have used classification alogrithms such as:[logistics_regresion, KNN, SVM classifier , Decisiion_tree, RandomForest_classifer],from all alogrithms the actual_value and predicated Outputs were  same , whereas when eveluate score of model comes Logistic_regression was best among all the models , to understand purpose a line chart is displayed above the box. which display evaluate_score as Y_axis and algorithms_name as X-axis.
